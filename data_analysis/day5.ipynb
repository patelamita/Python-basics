# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/Salary_Data.csv")

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6699     True
# 6700     True
# 6701     True
# 6702     True
# 6703     True
# Length: 6704, dtype: bool

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df["Education Level"]
# Out:
# 0              Bachelor's
# 1                Master's
# 2                     PhD
# 3              Bachelor's
# 4                Master's
#               ...
# 6699                  PhD
# 6700          High School
# 6701    Bachelor's Degree
# 6702      Master's Degree
# 6703          High School
# Name: Education Level, Length: 6704, dtype: object

# %%
df[["Age", 'Gender']]
# Out:
#        Age  Gender
# 0     32.0    Male
# 1     28.0  Female
# 2     45.0    Male
# 3     36.0  Female
# 4     52.0    Male
# ...    ...     ...
# 6699  49.0  Female
# 6700  32.0    Male
# 6701  30.0  Female
# 6702  46.0    Male
# 6703  26.0  Female
#
# [6704 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Age                                 32.0
# Gender                              Male
# Education Level               Bachelor's
# Job Title              Software Engineer
# Years of Experience                  5.0
# Salary                           90000.0
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df["Job Title"].value_counts()[:30]
# Out:
# Job Title
# Software Engineer                   518
# Data Scientist                      453
# Software Engineer Manager           376
# Data Analyst                        363
# Senior Project Engineer             318
# Product Manager                     313
# Full Stack Engineer                 309
# Marketing Manager                   255
# Senior Software Engineer            244
# Back end Developer                  244
# Front end Developer                 241
# Marketing Coordinator               158
# Junior Sales Associate              142
# Financial Manager                   134
# Marketing Analyst                   132
# Software Developer                  125
# Operations Manager                  114
# Human Resources Manager             104
# Director of Marketing                88
# Web Developer                        87
# Product Designer                     75
# Research Director                    75
# Content Marketing Manager            73
# ...

# %%
df["Education Level"].value_counts()
# Out:
# Education Level
# Bachelor's Degree    2267
# Master's Degree      1573
# PhD                  1368
# Bachelor's            756
# High School           448
# Master's              288
# phD                     1
# Name: count, dtype: int64

# %%
df["Education Level"].replace("PhD","phD")
# Out:
# 0              Bachelor's
# 1                Master's
# 2                     phD
# 3              Bachelor's
# 4                Master's
#               ...
# 6699                  phD
# 6700          High School
# 6701    Bachelor's Degree
# 6702      Master's Degree
# 6703          High School
# Name: Education Level, Length: 6704, dtype: object

# %%
df["Salary"].sort_values().head(10)
# Out:
# 259       350.0
# 4633      500.0
# 1890      550.0
# 2654      579.0
# 6046    25000.0
# 4121    25000.0
# 4136    25000.0
# 4129    25000.0
# 4084    25000.0
# 4054    25000.0
# Name: Salary, dtype: float64

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 140000.0    287
# 120000.0    282
# 160000.0    276
# 55000.0     251
# 60000.0     231
#            ...
# 148437.0      1
# 168691.0      1
# 138000.0      1
# 174000.0      1
# 68000.0       1
# Name: count, Length: 444, dtype: int64

# %%
sns.histplot(data=df, x="Salary", kde=True, bins=20)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sizes = df["Education Level"].value_counts()
labels = df["Education Level"].value_counts().index

plt.figure(figsize=(5,5))
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Education Level")
# Out:
# Text(0.5, 1.0, 'Education Level')

# %%
sns.lineplot(x = "Age", y = "Salary", data = df, hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
# Average salary for males and females
print(df.groupby('Gender')['Salary'].mean())
# Out:
# Gender
# Female    107888.998672
# Male      121389.870915
# Other     125869.857143
# Name: Salary, dtype: float64

# %%
# Check how age, experience, and salary are related
correlation_matrix = df[['Age', 'Years of Experience', 'Salary']].corr()
print(correlation_matrix)
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.937655  0.728053
# Years of Experience  0.937655             1.000000  0.808969
# Salary               0.728053             0.808969  1.000000

# %%
sns.histplot(df['Age'], bins=5, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.barplot(x='Gender', y='Salary', data=df, estimator=np.mean)
plt.title('Average Salary by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Salary')
plt.show()

# %%
sns.scatterplot(x='Years of Experience', y='Salary', hue='Gender', data=df)
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
# sns.boxplot(x='Education Level', y='Salary', data=df)
# plt.title('Salary Distribution by Education Level')
# plt.xlabel('Education Level')
# plt.ylabel('Salary')
# # plt.show()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Average salary by job title
print(df.groupby('Job Title')['Salary'].mean())

# Salary by education level and gender
print(df.groupby(['Education Level', 'Gender'])['Salary'].mean())
# Out:
# Job Title
# Account Manager              75000.000000
# Accountant                   55000.000000
# Administrative Assistant     50000.000000
# Back end Developer          102352.561475
# Business Analyst             77500.000000
#                                 ...
# UX Designer                  80000.000000
# UX Researcher                65000.000000
# VP of Finance               200000.000000
# VP of Operations            190000.000000
# Web Developer                66436.781609
# Name: Salary, Length: 193, dtype: float64
# Education Level    Gender
# Bachelor's         Female    114542.253521
#                    Male      130920.233051
# Bachelor's Degree  Female     81280.014223
#                    Male       87809.906736
# High School        Female     30756.047809
#                    Male       39380.751351
#                    Other     119949.333333
# Master's           Female    160201.005025
#                    Male      151797.752809
# ...
