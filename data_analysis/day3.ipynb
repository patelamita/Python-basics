# %%
import random

# Generate a random number
random_num = random.randint(1, 100)
print("Let's guess the number!")


for i in range(1, 11):
    number = int(input("Enter a number: "))
    
    if number > random_num:
        print("Number is too high")
    elif number < random_num:
        print("Number is too low")
    else:
        print(f" You guessed the correct number: {random_num}")
        break  
else:
    print(f"Sorry, you've used all attempts. The number was {random_num}.")
# Out:
# Let's guess the number!

# %%
import os

# %%
import pandas as pd

df = pd.read_csv("C:/Users/User/python/datasets/Salary_Data.csv")

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df[["Age","Gender","Salary"]]
# Out:
#        Age  Gender    Salary
# 0     32.0    Male   90000.0
# 1     28.0  Female   65000.0
# 2     45.0    Male  150000.0
# 3     36.0  Female   60000.0
# 4     52.0    Male  200000.0
# ...    ...     ...       ...
# 6699  49.0  Female  200000.0
# 6700  32.0    Male   50000.0
# 6701  30.0  Female   55000.0
# 6702  46.0    Male  140000.0
# 6703  26.0  Female   35000.0
#
# [6704 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.iloc[1:5,1:5]
# Out:
#    Gender Education Level        Job Title  Years of Experience
# 1  Female        Master's     Data Analyst                  3.0
# 2    Male             PhD   Senior Manager                 15.0
# 3  Female      Bachelor's  Sales Associate                  7.0
# 4    Male        Master's         Director                 20.0

# %%
df.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
df.shape
# Out:
# (2005, 28)

# %%
len(df)
# Out:
# 2005

# %%
df.info
# Out:
# <bound method DataFrame.info of      industry  occupation  yrs_qual  sex  highest_qual  area_of_study  \
# 0           Q           2        19    1            13              4
# 1           C           9        14    1            11              7
# 2           L           3        16    2            12              4
# 3           Q           5        12    2             7              4
# 4           P           1        18    1            13              4
# ...       ...         ...       ...  ...           ...            ...
# 2000        N           3        12    2             7              8
# 2001        C           3        16    1            12              4
# 2002        Q           1        18    2            13              4
# 2003        M           4        12    2             7              4
# 2004        G           5        12    2             7              7
#
#       influencing  negotiating  sector  workforce_change  ...  advising  \
# ...

# %%
df.describe()
# Out:
#         occupation     yrs_qual          sex  highest_qual  area_of_study  \
# count  2005.000000  2005.000000  2005.000000   2005.000000    2005.000000
# mean      4.078304    13.877805     1.520200      9.310723       4.104738
# std       2.472676     2.767168     0.499716      3.059247       2.605844
# min       0.000000     6.000000     1.000000      1.000000       0.000000
# 25%       2.000000    12.000000     1.000000      7.000000       2.000000
# 50%       3.000000    13.000000     2.000000      9.000000       4.000000
# 75%       5.000000    16.000000     2.000000     12.000000       6.000000
# max      15.000000    21.000000     2.000000     15.000000       9.000000
#
#        influencing  negotiating       sector  workforce_change  \
# count  2005.000000  2005.000000  2005.000000       2005.000000
# mean      3.316209     2.762594     1.385536          2.296758
# std       1.682291     1.701384     0.621063          0.865284
# ...

# %%
# Display the first 5 rows
print(df.head())

# Display the last 5 rows
print(df.tail())

# Get the shape of the DataFrame (rows, columns)
print(df.shape)

# Get summary statistics for numeric columns
print(df.describe())

# Get information about the DataFrame (column names, data types, non-null counts)
print(df.info())

# Check for missing values
print(df.isnull().sum())


# Select a single column
print(df['column_name'])

# Select multiple columns
print(df[['column1', 'column2']])

# Select rows by index
print(df.iloc[0])  # First row
print(df.iloc[0:5])  # First 5 rows

# Select rows by condition
print(df[df['column_name'] > 50])  # Rows where column_name > 50
